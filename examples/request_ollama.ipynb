# %% [markdown]
# # Udinh Ollama via PromptSail
#
#
# ## Prerequisites
#
# 1. To run this example you need to install dependencies from [examples/pyproject.toml](pyproject.toml) by running the following command:
#     ```bash
#     cd prompt_sail/examples
#     poetry install
#     ```
# 1. Download Ollama from [main ollama page](https://ollama.com/)
# 1. Download your model via console (if you are trying to use it first time)
# for example with that command for llama3:
#     ```bash
#     ollama run llama3
#     ```
# 1. Setup project and AI provider in Prompt Sail dashboard,
#     - [Run the PromptSail docker images](https://promptsail.com/docs/quick-start-guide/#pull-and-run-the-docker-images-from-ghcr) and go to UI at http://localhost/.
#     - Create new project with you `project_slug`or edit existing one.
#     - Add new provider for your project on PromptSail main page for example:
#         ```json
#         {
#             ...
#             slug: 'models-playground',
#             ...
#             ai_providers: [
#                 ...
#                 {
#                     deployment_name: 'ollama',
#                     slug: 'ollama',
#                     api_base: 'http://host.docker.internal:11434/api/generate',
#                     description: '',
#                     provider_name: 'Ollama'
#                 }
#             ],
#             ...
#         ```
# 1. Now using project slug and provider slug you can get access to your models ```http://localhost:8000/models-playground/ollama/```

# %%
import requests
from rich import print

body = {
    "model": "mistral",
    "prompt": "Here is a story about llamas eating grass"
}

response = requests.post("http://localhost:8000/models-playground/ollama/", json=body)

print(response.content)
# Out:
# b'{"model":"mistral","created_at":"2024-06-25T21:47:38.9274469Z","response":" Title","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:38.9412163Z","response":":","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:38.9533875Z","response":" The","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:38.967333Z","response":" G","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:38.9811511Z","response":"raz","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:38.9942013Z","response":"ing","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.0077517Z","response":" Guard","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.0210411Z","response":"ians","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.034205Z","response":" of","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.0476461Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.0610509Z","response":" And","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.074211Z","response":"es","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.0878664Z","response":"\\n","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1010858Z","response":"\\n","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1146429Z","response":"In","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1276798Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1407614Z","response":" maj","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1542535Z","response":"estic","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1674373Z","response":" he","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.181058Z","response":"ights","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.1940397Z","response":" of","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2066549Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2206411Z","response":" And","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2334906Z","response":"es","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2471634Z","response":",","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2606296Z","response":" where","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2737693Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2868354Z","response":" sky","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.2998053Z","response":" meets","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3130538Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3262036Z","response":" earth","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3397726Z","response":" in","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3530855Z","response":" a","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3668074Z","response":" dance","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3807934Z","response":" of","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.3936467Z","response":" eth","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.4069466Z","response":"ere","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.4206525Z","response":"al","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.4342067Z","response":" beauty","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.4471304Z","response":",","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.4605435Z","response":" there","done":false}\n{"model":"mistral","created_at":"2024-06-25T21:47:39.4738393Z","response":" ex ...

# %%
# This function concatenates streamed response content into one string
def get_answer(response):
    return "".join(list(map(lambda msg: [text for text in [text for text in msg[1:-1].split('response":"')][1].split('"')][0], response.content.decode('utf-8').split('\n')[:-2])))

# %%
content = get_answer(response)
print(content)
# Out:
#  Title: The Llamas' Green Feast\n\nIn the heart of the Andean highlands, where the sky meets the earth in a breathtaking expanse of blue and green, lived a small herd of llamas. These resilient creatures were known for their distinctive long necks, humps, and soft, gentle eyes that held wisdom beyond their years.\n\nEvery dawn, as the sun began to peek over the mountains, the llamas would venture out from their shelters, ready to embark on a new day. Their days were simple but purposeful - filled with grazing, socializing, and enjoying the serene beauty of their surroundings.\n\nOne particular morning, as the first light of day kissed the grassy plains, the llamas noticed something unusual. A patch of lush, vibrant green grass had appeared overnight, unlike anything they had ever seen before. Intrigued, they approached the mysterious plot cautiously.\n\nAs they tentatively took their first bites, their eyes widened in delight. This wasn't just any grass; it was a feast like no other - tender, sweet, and incredibly nourishing. The llamas had never tasted anything quite so delectable. They grazed contentedly, their long tongues flickering gracefully as they devoured the verdant delicacy.\n\nThe word spread quickly among the herd, and soon, all the llamas were gathered around this magical patch of grass. Their joy was infectious; even the most reserved members of the herd couldn't help but join in the feast. The air was filled with contented murmurs and the gentle sound of llamas munching on their newfound treasure.\n\nDays turned into weeks, and the patch of grass continued to thrive, providing the llamas with a bountiful feast. They flourished under its nourishment, their coats becoming glossier, their steps more energetic. The herd had never been healthier or happier.\n\nThe story of the magical grass spread far and wide, reaching the humans who lived at the foot of the Andes. They marveled at this wondrous phenomenon and sought to learn more about it. Scholars, botanists, and curious travelers flocked to the highlands to study the grass and witness the spectacle firsthand.\n\nAs the days went by, the humans and llamas formed a bond - a mutual respect and admiration for each other's wisdom and resilience. Together, they shared stories, knowledge, and laughter as the days turned into weeks, and the weeks into years. The magical grass remained, a symbol of their unique friendship and the wonders that lay hidden in the Andean highlands.\n\nAnd so, the llamas continued to graze upon their green feast, nourishing their bodies and strengthening their bond with the humans who had come to share in their simple yet extraordinary life. The days were filled with contentment, laughter, and a shared appreciation for the beauty of nature that surrounded them all. And as they gazed out over the vibrant plains, they knew that they were truly blessed - for in this magical place, where the sun kissed the earth and grass grew like dreams, they had found their home.

# %%
body_llama = {
  "model": "llama3",
  "prompt":"Why is the sky blue?"
}

response_llama = requests.post("http://localhost:11434/api/generate", json=body_llama)
print(response_llama.content)
# Out:
# b'{"model":"llama3","created_at":"2024-06-25T21:36:09.5672721Z","response":"A","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.5820144Z","response":" classic","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.5980477Z","response":" question","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.6123808Z","response":"!\\n\\n","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.627917Z","response":"The","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.643596Z","response":" sky","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.6581295Z","response":" appears","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.6733633Z","response":" blue","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.689409Z","response":" because","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.7041594Z","response":" of","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.7195445Z","response":" a","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.7347163Z","response":" phenomenon","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.7495217Z","response":" called","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.7650598Z","response":" scattering","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.779466Z","response":",","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.7946775Z","response":" which","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.8088416Z","response":" occurs","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.8247993Z","response":" when","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.8400846Z","response":" sunlight","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.8548339Z","response":" interacts","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.8694958Z","response":" with","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.8847149Z","response":" tiny","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.899291Z","response":" molecules","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.9148363Z","response":" of","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.9293717Z","response":" gases","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.9447962Z","response":" in","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.9595229Z","response":" the","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.9746567Z","response":" Earth","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:09.9901318Z","response":"\'s","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.0047391Z","response":" atmosphere","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.0199276Z","response":".","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.0354387Z","response":" Here","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.050051Z","response":"\'s","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.0655296Z","response":" a","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.0803599Z","response":" simplified","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.0955979Z","response":" explanation","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.1099152Z","response":":\\n\\n","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.1256504Z","response":"1","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.140743Z","response":".","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.1553787Z","response":" **","done":false}\n{"model":"llama3","created_at":"2024-06-25T21:36:10.1709049Z","response":"Sun","done":false}\n{"model":"llama3","created_at":"2024-06-25T2 ...

# %%
content_llama = get_answer(response_llama)
print(content_llama)
# Out:
# A classic question!\n\nThe sky appears blue because of a phenomenon called scattering, which occurs when sunlight interacts with tiny molecules of gases in the Earth's atmosphere. Here's a simplified explanation:\n\n1. **Sunlight**: The sun emits light across the entire electromagnetic spectrum, including all the colors of the rainbow (red, orange, yellow, green, blue, indigo, and violet).\n2. **Atmosphere**: When this sunlight enters the Earth's atmosphere, it encounters tiny molecules of gases like nitrogen (N2) and oxygen (O2). These molecules are much smaller than the wavelength of light.\n3. **Scattering**: The small gas molecules scatter the shorter, blue wavelengths of light more efficiently than the longer, red wavelengths. This is known as Rayleigh scattering, named after the British physicist Lord Rayleigh, who first described the phenomenon in the late 19th century.\n4. **Blue dominance**: As a result of this scattering, the blue light is dispersed throughout the atmosphere, reaching our eyes from all directions. Since we see the sky from all sides, it appears blue to us.\n\nOther factors can affect the apparent color of the sky, such as:\n\n* **Dust and water vapor**: These particles can scatter light in a way that makes the sky appear more hazy or gray.\n* **Clouds**: Clouds can reflect and scatter sunlight, making the sky appear whiter or grayer.\n* **Time of day and year**: The angle of the sun and the amount of atmospheric scattering can vary depending on the time of day and year, influencing the perceived color of the sky.\n\nSo, to summarize: the sky appears blue because of the efficient scattering of shorter wavelengths (blue light) by tiny molecules in the Earth's atmosphere.

# %%
content_llama = "".join(list(map(lambda msg: [text for text in [text for text in msg[1:-1].split('response":"')][1].split('"')][0], content_llama)))
print(content_llama)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 content_llama = "".join(list(map(lambda msg: [text for text in [text for text in msg[1:-1].split('response":"')][1].split('"')][0], content_llama)))
#       2 print(content_llama)
#
# Cell In[8], line 1, in <lambda>(msg)
# ----> 1 content_llama = "".join(list(map(lambda msg: [text for text in [text for text in msg[1:-1].split('response":"')][1].split('"')][0], content_llama)))
#       2 print(content_llama)
#
# IndexError: list index out of range
