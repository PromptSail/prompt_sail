# %% [markdown]
# # If you want to use your Ollama via PromptSail then you need to follow this steps:
# 1. Download Ollama from [main ollama page](https://ollama.com/)
# 2. Download your model via console (if you are trying to use it first time)
# for example with that command for llama3: ```ollama run llama3```
# 3. Add new provider for your project on PromptSail main page
# for example:
# ```json
# {
#     ...
#     slug: 'models-playground',
#     ...
#     ai_providers: [
#         ...
#         {
#             deployment_name: 'ollama',
#             slug: 'ollama',
#             api_base: 'http://localhost:11434/api/generate',
#             description: '',
#             provider_name: 'Ollama'
#         }
#     ],
#     ...
# ```
# 4. Now using project slug and provider slug you can get access to your models ```http://localhost:8000/models-playground/ollama/```

# %%
import requests

body = {
    "model": "mistral",
    "prompt": "Here is a story about llamas eating grass"
}

response = requests.post("http://localhost:8000/models-playground/ollama/", json=body)

print(response.content)
# Out:
# b'{"model":"mistral","created_at":"2024-06-24T15:51:41.9386861Z","response":" Title","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.0626579Z","response":":","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.1168518Z","response":" The","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.1328928Z","response":" L","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.1474528Z","response":"lam","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.1623668Z","response":"as","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.1769628Z","response":" of","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.1908763Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2050826Z","response":" Great","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2187466Z","response":" Pl","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2320805Z","response":"ains","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2469263Z","response":":","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2609561Z","response":" A","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2778978Z","response":" T","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.2927729Z","response":"ale","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.3059152Z","response":" of","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.3200638Z","response":" G","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.3346816Z","response":"raz","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.3493415Z","response":"ing","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.366859Z","response":" Harm","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.3813429Z","response":"ony","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.3950921Z","response":"\\n","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.4086705Z","response":"\\n","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.4219478Z","response":"In","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.4348699Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.4482877Z","response":" vast","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.4615103Z","response":",","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.4753225Z","response":" swe","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.48957Z","response":"eping","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5028147Z","response":" exp","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5156903Z","response":"anse","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5288412Z","response":" of","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5426596Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5563272Z","response":" Great","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5699562Z","response":" Pl","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5837881Z","response":"ains","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.5968009Z","response":",","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.6102216Z","response":" where","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.6243051Z","response":" the","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.6372472Z","response":" sky","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.6510915Z","response":" met","done":false}\n{"model":"mistral","created_at":"2024-06-24T15:51:42.6649515Z","response":" the","done":fa ...

# %%
# This function concatenates streamed response content into one string
def get_answer(response):
    return "".join(list(map(lambda msg: [text for text in [text for text in msg[1:-1].split('response":"')][1].split('"')][0], response.content.decode('utf-8').split('\n')[:-2])))

# %%
content = get_answer(response)
print(content)
# Out:
#  Title: The Llamas of the Great Plains: A Tale of Grazing Harmony\n\nIn the vast, sweeping expanse of the Great Plains, where the sky met the earth in an endless dance of light and shadow, there existed a unique ecosystem teeming with life. Among the multitude of creatures that called this land home, none were as iconic, nor as harmonious in their existence, as the llamas.\n\nThese majestic animals roamed freely across the plains, their silhouettes often painted against the setting sun like moving artifacts from a distant time. They were known for their gentle demeanor and unique ability to adapt to their environment. Most importantly, they played a crucial role in maintaining the balance of the grasslands by grazing sustainably.\n\nThe llamas had a peculiar diet consisting primarily of various species of grasses that thrived in the Great Plains. These grasses were not only essential for the survival of the llamas but also served as a vital food source for many other animals, from tiny insects to large herbivores. The llamas' grazing pattern was carefully designed by nature to ensure that no single area was overgrazed, allowing the grasses time to regrow and maintain the health of the ecosystem.\n\nOne day, a young llama named Pacha found himself in a peculiar situation. He had strayed from his herd while exploring an unfamiliar part of the plains. As he wandered, he noticed something unusual - a patch of grass that seemed to be struggling. The plants were smaller and paler than those around them, and there was an air of desperation about them.\n\nPacha, being a curious and compassionate llama, decided to investigate further. He nibbled gently at the stricken grass, noticing that it tasted different from the lush, green blades he was accustomed to. He realized that this patch had been overgrazed, possibly by a herd passing through unknowingly.\n\nDetermined to help, Pacha spread out his herding instincts and gathered the other llamas in the area to follow him. Together, they moved systematically across the plains, avoiding areas already grazed and focusing on patches of healthy grass that needed a light trim. The llama herd, unknowingly led by Pacha, worked together to restore balance to their home.\n\nAs the days turned into weeks, the once struggling patch began to thrive. The other animals noticed the change and soon joined in, feeding on the revitalized grasses. The Great Plains returned to its former glory, a testament to the harmony between nature and these gentle creatures.\n\nPacha's actions not only saved that particular area but also served as a reminder to all the llamas of their crucial role in maintaining the balance of their ecosystem. They continued to graze sustainably, moving with purpose and respect for the land they called home. And so, the tale of Pacha and the llamas of the Great Plains became a symbol of harmony and cooperation between creatures and their environment.

# %%
body_llama = {
  "model": "llama3",
  "prompt":"Why is the sky blue?"
}

response_llama = requests.post("http://localhost:11434/api/generate", json=body_llama)
print(response_llama.content)
# Out:
# b'{"model":"llama3","created_at":"2024-06-24T15:53:48.3793618Z","response":"What","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.3930109Z","response":" a","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.4074385Z","response":" great","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.4218643Z","response":" question","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.436906Z","response":"!\\n\\n","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.450865Z","response":"The","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.4663524Z","response":" sky","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.4809175Z","response":" appears","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.4944881Z","response":" blue","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.5099786Z","response":" because","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.524428Z","response":" of","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.5389915Z","response":" a","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.5537165Z","response":" phenomenon","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.5676828Z","response":" called","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.5829815Z","response":" Ray","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.5966806Z","response":"leigh","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.6116468Z","response":" scattering","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.6257045Z","response":",","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.6401433Z","response":" named","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.6548511Z","response":" after","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.669573Z","response":" the","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.6841682Z","response":" British","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.6982301Z","response":" physicist","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.7130477Z","response":" Lord","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.727518Z","response":" Ray","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.7419086Z","response":"leigh","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.7571408Z","response":".","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.7719218Z","response":" He","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.7851715Z","response":" discovered","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.8003017Z","response":" that","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.8145416Z","response":" shorter","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.8290443Z","response":" wavelengths","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.8435846Z","response":" of","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.8586789Z","response":" light","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.873076Z","response":" (","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.8881301Z","response":"like","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.9030593Z","response":" blue","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.9173107Z","response":" and","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.9317494Z","response":" violet","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.9461115Z","response":")","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53:48.9606769Z","response":" are","done":false}\n{"model":"llama3","created_at":"2024-06-24T15:53: ...

# %%
content_llama = get_answer(response_llama)
print(content_llama)
# Out:
# What a great question!\n\nThe sky appears blue because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh. He discovered that shorter wavelengths of light (like blue and violet) are scattered more than longer wavelengths (like red and orange) by tiny particles in the atmosphere.\n\nHere's what happens:\n\n1. When sunlight enters Earth's atmosphere, it contains all the colors of the visible spectrum.\n2. The tiny molecules of gases like nitrogen (N2) and oxygen (O2), as well as aerosols like dust, water vapor, and pollutants, scatter this light.\n3. Shorter wavelengths (blue and violet) are scattered more than longer wavelengths (red and orange) because they have more energy and interact more strongly with the small particles in the air.\n4. As a result, our eyes perceive the scattered blue light as dominant, making the sky appear blue.\n\nSome additional factors that contribute to the blue color of the sky:\n\n1. Mie scattering: Larger particles like water droplets or ice crystals can scatter longer wavelengths (like red and orange) more effectively, adding warmth and depth to the sky.\n2. Atmospheric conditions: Weather patterns, pollution levels, and other atmospheric conditions can alter the apparent color of the sky. For example, during sunrise and sunset, the angle of the sun and the scattering of light by particles in the atmosphere create warm hues like orange and red.\n\nIn summary, the blue color of the sky is primarily due to Rayleigh scattering, where shorter wavelengths of light are scattered more than longer wavelengths by tiny particles in the atmosphere.

# %%
content_llama = "".join(list(map(lambda msg: [text for text in [text for text in msg[1:-1].split('response":"')][1].split('"')][0], content_llama)))
print(content_llama)
# Out:
# The color of the sky is a fascinating topic that has puzzled people for centuries. So, why is the sky blue?\n\nIn short, the sky appears blue because of a combination of factors involving light, atmosphere, and our perception.\n\nHere's the main reason:\n\n1. **Scattering of sunlight**: When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases like nitrogen (N2) and oxygen (O2). These molecules scatter shorter (blue) wavelengths of light more than longer (red) wavelengths. This phenomenon is called Rayleigh scattering.\n2. **Blue light dominance**: As a result of this scattering, the blue light is dispersed throughout the atmosphere in all directions. Since our eyes are more sensitive to blue light, we perceive the scattered blue light as the color of the sky.\n3. **Atmospheric conditions**: Other factors that influence the apparent color of the sky include:\n\t* Atmospheric particles: Tiny particles like dust, water vapor, and pollutants can scatter light in different ways, affecting the perceived color.\n\t* Clouds: Clouds can reflect and absorb light, changing the color of the sky.\n\t* Altitude: The color of the sky can appear more blue at higher altitudes because there's less atmospheric scattering.\n\nNow, let's dive a bit deeper:\n\n**Red light dominance**: When you look directly at the sun or a bright red object, you'll notice that it appears more orange or yellowish. This is because longer wavelengths (like red and orange) are not scattered as much by the atmosphere, so they reach your eyes with less scattering.\n\n**Perception**: The color of the sky can also be influenced by our perception. For example:\n\t* Brightness: A bright blue sky can appear more intense than a dull gray one.\n\t* Color constancy: Our brains are wired to adjust for changes in lighting conditions, which can affect how we perceive the color of the sky.\n\nIn summary, the sky appears blue because of the scattering of sunlight by tiny molecules in the atmosphere, combined with our perception and the influence of atmospheric conditions.
